# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
import pandas as pd
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2

# %%
df['target'] = iris.target

# %%
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df[df.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target
# 100       2
# 101       2
# 102       2
# 103       2
# 104       2

# %%
df[df.target==0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['flower name'] = df.target.apply(lambda x : iris.target_names[x])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target flower name
# 0         0      setosa
# 1         0      setosa
# 2         0      setosa
# 3         0      setosa
# 4         0      setosa
# ..      ...         ...
# 145       2   virginica
# 146       2   virginica
# 147       2   virginica
# 148       2   virginica
# 149       2   virginica
#
# [150 rows x 6 columns]

# %%
df[45:55]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower name
# 45       0      setosa
# 46       0      setosa
# 47       0      setosa
# 48       0      setosa
# 49       0      setosa
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %%
df[95:105]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 95                 5.7               3.0                4.2               1.2
# 96                 5.7               2.9                4.2               1.3
# 97                 6.2               2.9                4.3               1.3
# 98                 5.1               2.5                3.0               1.1
# 99                 5.7               2.8                4.1               1.3
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower name
# 95        1  versicolor
# 96        1  versicolor
# 97        1  versicolor
# 98        1  versicolor
# 99        1  versicolor
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
import matplotlib.pyplot as plt
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color='green', marker= '*')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'], color='blue', marker='d')

# %%
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'])
plt.scatter(df2['petal length (cm)'], df2['petal width (cm)'])

# %%
from sklearn.svm import SVC
model = SVC()

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['target', 'flower name'], axis='columns')

# %%
y = df.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
model.predict([[6.5, 2.8, 4.6,1.5]])
# Out:
# C:\Users\s_nas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1])

# %%
x_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 54                 6.5               2.8                4.6               1.5
# 83                 6.0               2.7                5.1               1.6
# 60                 5.0               2.0                3.5               1.0
# 8                  4.4               2.9                1.4               0.2
# 23                 5.1               3.3                1.7               0.5
# 112                6.8               3.0                5.5               2.1
# 31                 5.4               3.4                1.5               0.4
# 106                4.9               2.5                4.5               1.7
# 30                 4.8               3.1                1.6               0.2
# 50                 7.0               3.2                4.7               1.4
# 137                6.4               3.1                5.5               1.8
# 3                  4.6               3.1                1.5               0.2
# 75                 6.6               3.0                4.4               1.4
# 20                 5.4               3.4                1.7               0.2
# 4                  5.0               3.6                1.4               0.2
# 96                 5.7               2.9                4.2               1.3
# 67                 5.8               2.7                4.1               1.0
# 120                6.9               3.2                5.7               2.3
# 33                 5.5               4.2                1.4               0.2
# 7                  5.0               3.4                1.5               0.2
# 39                 5.1               3.4                1.5               0.2
# 139                6.9               3.1                5.4               2.1
# 109                7.2               3.6                6.1               2.5
# 35                 5.0               3.2                1.2               0.2
# 21                 5.1               3.7                1.5               0.4
# 10                 5.4               3.7                1.5               0.2
# 25                 5.0               3.0                1.6               0.2
# 88                 5.6               3.0                4.1               1.3
# 81                 5.5               2.4                3.7               1.0
# 107                7.3               2.9                6.3               1.8
# 59                 5.2               2.7                3.9               1.4
# 73                 6.1               2.8                4.7               1.2
# 104                6.5               3.0                5.8               2.2
# 6                  4.6               3.4                1.4               0.3
# 123                6.3               2.7                4.9               1.8
# 24                 4.8               3.4                1.9               0.2
# 138                6.0               3.0                4.8               1.8
# 65                 6.7               3.1                4.4               1.4

# %%
y_test
# Out:
# 54     1
# 83     1
# 60     1
# 8      0
# 23     0
# 112    2
# 31     0
# 106    2
# 30     0
# 50     1
# 137    2
# 3      0
# 75     1
# 20     0
# 4      0
# 96     1
# 67     1
# 120    2
# 33     0
# 7      0
# 39     0
# 139    2
# 109    2
# 35     0
# 21     0
# 10     0
# 25     0
# 88     1
# 81     1
# 107    2
# 59     1
# 73     1
# 104    2
# 6      0
# 123    2
# 24     0
# 138    2
# 65     1
# Name: target, dtype: int32

# %%
model.score(x_test, y_test)
# Out:
# 0.9210526315789473
